# %%
import waveforms
import numpy as np
from matplotlib import pyplot as plt

frequency=60000
phase=0
samplerate=41000
time=np.arange(0, 225, 1)
p = waveforms.phasor(frequency, phase, samplerate, time)
saw = p.get_block_of_samples()

plt.plot(saw)
